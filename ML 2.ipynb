# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("AWCustomers.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [2], in <cell line: 1>()
# ----> 1 df=pd.read_csv("AWCustomers.csv")
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %%
df.sample(5)
# Out:
#        CustomerID Title FirstName MiddleName LastName Suffix  \
# 17793       20632   NaN    Marcus          R  Stewart    NaN
# 16261       13939   NaN   Eduardo        NaN  Ramirez    NaN
# 3985        17814   NaN   Michele        NaN      Pal    NaN
# 14973       13195   NaN     Aaron        NaN    Perry    NaN
# 9621        24509   NaN      Emma          F     Long    NaN
#
#               AddressLine1 AddressLine2           City StateProvinceName  ...  \
# 17793    4900 La Salle St.          NaN       Victoria  British Columbia  ...
# 16261        352 Margo Dr.          NaN        Burbank        California  ...
# 3985   444 Northstar Drive          NaN         London           England  ...
# 14973     7838 Euclid Ave.          NaN  San Francisco        California  ...
# 9621      3967 High Street          NaN        Spokane        Washington  ...
#
#              Education      Occupation Gender MaritalStatus HomeOwnerFlag  \
# ...

# %%
df.drop("Title",axis='columns')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
# ----> 1 df.drop("Title",axis='columns')
#
# NameError: name 'df' is not defined

# %%
df=df.drop("Suffix",axis='columns')
df=df.drop("LastUpdated",axis='columns')
df=df.drop("AddressLine2",axis='columns')

# %%
df=df.drop("BirthDate",axis='columns')

# %%
df.sample(5)
# Out:
#        CustomerID FirstName MiddleName   LastName           AddressLine1  \
# 15893       19927     Ruben        NaN  Fernandez       989 Caravelle Ct
# 4954        26256    Ronald        NaN       Rana  8974 F Mt Hood Circle
# 14417       11364  Jennifer        NaN    Collins    4536 Killdeer Court
# 2407        27639      Emma          H      Price    3886 Delta View Ln.
# 5302        13611  Marshall          L      Huang    33, quai de l´ Iton
#
#               City StateProvinceName CountryRegionName PostalCode  \
# 15893      W. York           England    United Kingdom    BD1 4SJ
# 4954       Ballard        Washington     United States      98107
# 14417      Geelong          Victoria         Australia       3220
# 2407   Walla Walla        Washington     United States      99362
# 5302        Sèvres    Hauts de Seine            France      92310
#
#                PhoneNumber            Education      Occupation Gender  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder
labelEncoder=LabelEncoder()

df["Gender"]=labelEncoder.fit_transform(df["Gender"])
df["MaritalStatus"]=labelEncoder.fit_transform(df["MaritalStatus"])

# %%
df.sample(5)
# Out:
#        CustomerID FirstName MiddleName  LastName           AddressLine1  \
# 13779       18204   Tiffany        NaN       Cai    7392 Coachman Place
# 10990       12062    Edward          H      Long       9837 Larkwood Ct
# 14548       15637   Russell          A    Sharma  6, route de Marseille
# 1611        21079       Lee          S   Carlson       2062 Dos Encinas
# 11181       18886    Donald          E  McDonald    2309 Mt. Olivet Ct.
#
#               City  StateProvinceName CountryRegionName PostalCode  \
# 13779  Rockhampton         Queensland         Australia       4700
# 10990   San Carlos         California     United States      94070
# 14548   Saint Ouen  Charente-Maritime            France      17490
# 1611     Wokingham            England    United Kingdom   RG41 1QW
# 11181      Ballard         Washington     United States      98107
#
#                PhoneNumber            Education      Occupation  Gender  \
# ...

# %%
from sklearn.preprocessing import OneHotEncoder
# enc=OneHotEncoder(sparse='False',handle_unknown='error',drop='first')
df= pd.get_dummies(df, columns = ['Education', 'Occupation'])

# %%
df.sample(5)
# Out:
#        CustomerID FirstName MiddleName  LastName             AddressLine1  \
# 350         22117    Sydney          C     Perez      2402 Sutherland Dr.
# 2958        16854      Seth          L     Adams            903 West I St
# 13481       19650   Sabrina          A      Sanz      5331 Buskrik Avenue
# 1105        25594     Cindy          T  Malhotra  2, rue de la Centenaire
# 1775        23589    Amanda        NaN     Baker        1077 Willow Court
#
#                  City  StateProvinceName CountryRegionName PostalCode  \
# 350         Vancouver   British Columbia            Canada    V7L 4J4
# 2958   Woodland Hills         California     United States      91364
# 13481   East Brisbane         Queensland         Australia       4169
# 1105           Pantin  Seine Saint Denis            France      93500
# 1775   Imperial Beach         California     United States      91932
#
#                PhoneNumber  ...  Education_Bachelors  \
# ...

# %%
to_drop=['FirstName','MiddleName','LastName','AddressLine1','CustomerID']

# %%
df=df.drop(to_drop,axis='columns')

# %%
df.sample(5)
# Out:
#                 City StateProvinceName CountryRegionName PostalCode  \
# 11477  Sedro Woolley        Washington     United States      98284
# 14157        W. Linn            Oregon     United States      97068
# 1954         Shawnee  British Columbia            Canada    V9B 2C3
# 4206          Yakima        Washington     United States      98901
# 11583      Bracknell           England    United Kingdom   RG12 8TB
#
#                PhoneNumber  Gender  MaritalStatus  HomeOwnerFlag  \
# 11477         358-555-0178       1              1              0
# 14157         807-555-0154       0              1              0
# 1954          505-555-0125       1              1              1
# 4206          609-555-0146       1              0              1
# 11583  1 (11) 500 555-0136       1              0              1
#
#        NumberCarsOwned  NumberChildrenAtHome  ...  Education_Bachelors  \
# 11477                0                     0  ...                    1
# ...

# %%
df.dtypes
# Out:
# City                             object
# StateProvinceName                object
# CountryRegionName                object
# PostalCode                       object
# PhoneNumber                      object
# Gender                            int64
# MaritalStatus                     int64
# HomeOwnerFlag                     int64
# NumberCarsOwned                   int64
# NumberChildrenAtHome              int64
# TotalChildren                     int64
# YearlyIncome                      int64
# Education_Bachelors               uint8
# Education_Graduate Degree         uint8
# Education_High School             uint8
# Education_Partial College         uint8
# Education_Partial High School     uint8
# Occupation_Clerical               uint8
# Occupation_Management             uint8
# Occupation_Manual                 uint8
# Occupation_Professional           uint8
# Occupation_Skilled Manual         uint8
# dtype: object

# %%
df.PhoneNumber
# Out:
# 0        1 (11) 500 555-0115
# 1               787-555-0136
# 2               120-555-0111
# 3        1 (11) 500 555-0167
# 4        1 (11) 500 555-0113
#                 ...
# 18356           292-555-0130
# 18357    1 (11) 500 555-0171
# 18358           819-555-0110
# 18359           791-555-0118
# 18360           553-555-0122
# Name: PhoneNumber, Length: 18361, dtype: object

# %%
df.PhoneNumber.values
# Out:
# array(['1 (11) 500 555-0115', '787-555-0136', '120-555-0111', ...,
#        '819-555-0110', '791-555-0118', '553-555-0122'], dtype=object)

# %%
df=df.drop("PhoneNumber",axis='columns')

# %%
df.sample(5)
# Out:
#             City    StateProvinceName CountryRegionName PostalCode  Gender  \
# 5974      Burien           Washington     United States      98168       1
# 4432      Hobart             Tasmania         Australia       7001       1
# 3254     Leipzig  Nordrhein-Westfalen           Germany       4139       1
# 529     El Cajon           California     United States      92020       0
# 10131  Paderborn              Hamburg           Germany      33041       1
#
#        MaritalStatus  HomeOwnerFlag  NumberCarsOwned  NumberChildrenAtHome  \
# 5974               0              1                1                     1
# 4432               0              0                2                     0
# 3254               0              0                0                     0
# 529                1              0                0                     0
# 10131              0              1                0                     1
#
# ...

# %%
cols_to_scale=['YearlyIncome','TotalChildren','NumberCarsOwned']
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
df[cols_to_scale] = scaler.fit_transform(df[cols_to_scale])

# %%
for col in df:
    print(f'{col}: {df[col].unique()}')
# Out:
# City: ['Wollongong' 'Shawnee' 'West Covina' 'Liverpool' 'Werne' 'Tacoma'
#  'Redwood City' 'Lavender Bay' 'Dunkerque' 'Metz' 'Lakewood' 'Los Angeles'
#  'Maidenhead' 'Beverly Hills' 'Puyallup' 'Langley' 'Darmstadt' 'Orly'
#  'El Cajon' 'Berlin' 'Oak Bay' 'Coronado' 'Hervey Bay' 'Drancy'
#  'Frankfurt' 'Findon' 'Newcastle' 'Morangis' 'Pantin' 'Sooke' 'Berkeley'
#  'Lemon Grove' 'Kassel' 'Courbevoie' 'Townsville' 'Woolston' 'Sèvres'
#  'La Jolla' 'Saint Ouen' 'Paris' 'St. Leonards' 'Saint-Denis' 'Oakland'
#  'Novato' 'Lane Cove' 'Suresnes' 'Cloverdale' 'Oregon City' 'Corvallis'
#  'Paderborn' 'Palo Alto' 'National City' 'Beaverton' 'Bury' 'Lebanon'
#  'Hobart' 'Runcorn' 'Solingen' 'Sedro Woolley' 'Hawthorne' 'Gold Coast'
#  'Port Hammond' 'Olympia' "Villeneuve-d'Ascq" 'Kirkland' 'Chula Vista'
#  'Braunschweig' 'Lincoln Acres' 'Lynnwood' 'Seattle' 'Torrance' 'Bottrop'
#  'Tremblay-en-France' 'München' 'Colombes' 'Ballard' 'Salem' 'Bracknell'
# ...

# %%
df=df.drop("PostalCode",axis='columns')

# %%
df=df.drop("City",axis='columns')

# %%
for col in df:
    print(f'{col}: {df[col].unique()}')
# Out:
# StateProvinceName: ['New South Wales' 'British Columbia' 'California' 'England'
#  'Nordrhein-Westfalen' 'Washington' 'Nord' 'Moselle' 'Hessen'
#  'Val de Marne' 'Queensland' 'Seine Saint Denis' 'South Australia'
#  'Essonne' 'Hauts de Seine' 'Somme' 'Seine (Paris)' 'Hamburg' 'Oregon'
#  'Tasmania' 'Victoria' 'Garonne (Haute)' 'Saarland' 'Yveline' 'Bayern'
#  "Val d'Oise" 'Charente-Maritime' 'Loiret' 'Illinois' 'Alberta'
#  'Brandenburg' 'North Carolina' 'Loir et Cher' 'Seine et Marne'
#  'Pas de Calais' 'Minnesota' 'South Carolina' 'Alabama' 'Virginia'
#  'Georgia' 'Missouri' 'Wyoming' 'Ohio' 'Arizona' 'Texas' 'Kentucky'
#  'Ontario' 'Florida' 'Mississippi' 'Utah' 'Massachusetts' 'New York'
#  'Montana' 'Maryland']
# CountryRegionName: ['Australia' 'Canada' 'United States' 'United Kingdom' 'Germany' 'France']
# Gender: [1 0]
# MaritalStatus: [0 1]
# HomeOwnerFlag: [1 0]
# NumberCarsOwned: [0.6 0.4 0.2 0.  0.8 1. ]
# NumberChildrenAtHome: [0 1 2 3]
# ...

# %%
df=df.drop("StateProvinceName",axis='columns')
df=df.drop("CountryRegionName",axis='columns')

# %%
for col in df:
    print(f'{col}: {df[col].unique()}')
# Out:
# Gender: [1 0]
# MaritalStatus: [0 1]
# HomeOwnerFlag: [1 0]
# NumberCarsOwned: [0.6 0.4 0.2 0.  0.8 1. ]
# NumberChildrenAtHome: [0 1 2 3]
# TotalChildren: [0.33333333 0.66666667 0.         1.        ]
# YearlyIncome: [0.49684201 0.48945285 0.53617171 ... 0.31278149 0.54312104 0.98012843]
# Education_Bachelors: [1 0]
# Education_Graduate Degree: [0 1]
# Education_High School: [0 1]
# Education_Partial College: [0 1]
# Education_Partial High School: [0 1]
# Occupation_Clerical: [1 0]
# Occupation_Management: [0 1]
# Occupation_Manual: [0 1]
# Occupation_Professional: [0 1]
# Occupation_Skilled Manual: [0 1]

# %%
df[pd.to_numeric(df.TotalChildren,errors='coerce').isnull()]
# Out:
# Empty DataFrame
# Columns: [Gender, MaritalStatus, HomeOwnerFlag, NumberCarsOwned, NumberChildrenAtHome, TotalChildren, YearlyIncome, Education_Bachelors, Education_Graduate Degree, Education_High School, Education_Partial College, Education_Partial High School, Occupation_Clerical, Occupation_Management, Occupation_Manual, Occupation_Professional, Occupation_Skilled Manual]
# Index: []

# %%
df.dropna()
# Out:
#        Gender  MaritalStatus  HomeOwnerFlag  NumberCarsOwned  \
# 0           1              0              1              0.6
# 1           1              0              1              0.4
# 2           0              1              0              0.6
# 3           1              0              1              0.4
# 4           1              1              1              0.2
# ...       ...            ...            ...              ...
# 18356       0              0              0              0.2
# 18357       0              1              0              0.4
# 18358       0              1              0              0.4
# 18359       0              1              0              0.0
# 18360       0              0              1              0.4
#
#        NumberChildrenAtHome  TotalChildren  YearlyIncome  Education_Bachelors  \
# 0                         0       0.333333      0.496842                    1
# ...

# %%
for col in df:
    print(f'{col}: {df[col].unique()}')
# Out:
# Gender: [1 0]
# MaritalStatus: [0 1]
# HomeOwnerFlag: [1 0]
# NumberCarsOwned: [0.6 0.4 0.2 0.  0.8 1. ]
# NumberChildrenAtHome: [0 1 2 3]
# TotalChildren: [0.33333333 0.66666667 0.         1.        ]
# YearlyIncome: [0.49684201 0.48945285 0.53617171 ... 0.31278149 0.54312104 0.98012843]
# Education_Bachelors: [1 0]
# Education_Graduate Degree: [0 1]
# Education_High School: [0 1]
# Education_Partial College: [0 1]
# Education_Partial High School: [0 1]
# Occupation_Clerical: [1 0]
# Occupation_Management: [0 1]
# Occupation_Manual: [0 1]
# Occupation_Professional: [0 1]
# Occupation_Skilled Manual: [0 1]

# %%
df = df.reset_index(drop = True)

# %%
df
# Out:
#        Gender  MaritalStatus  HomeOwnerFlag  NumberCarsOwned  \
# 0           1              0              1              0.6
# 1           1              0              1              0.4
# 2           0              1              0              0.6
# 3           1              0              1              0.4
# 4           1              1              1              0.2
# ...       ...            ...            ...              ...
# 18356       0              0              0              0.2
# 18357       0              1              0              0.4
# 18358       0              1              0              0.4
# 18359       0              1              0              0.0
# 18360       0              0              1              0.4
#
#        NumberChildrenAtHome  TotalChildren  YearlyIncome  Education_Bachelors  \
# 0                         0       0.333333      0.496842                    1
# ...

# %%
df=df.dropna()

# %%
df
# Out:
#        Gender  MaritalStatus  HomeOwnerFlag  NumberCarsOwned  \
# 0           1              0              1              0.6
# 1           1              0              1              0.4
# 2           0              1              0              0.6
# 3           1              0              1              0.4
# 4           1              1              1              0.2
# ...       ...            ...            ...              ...
# 18356       0              0              0              0.2
# 18357       0              1              0              0.4
# 18358       0              1              0              0.4
# 18359       0              1              0              0.0
# 18360       0              0              1              0.4
#
#        NumberChildrenAtHome  TotalChildren  YearlyIncome  Education_Bachelors  \
# 0                         0       0.333333      0.496842                    1
# ...
